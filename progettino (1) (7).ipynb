# %%
# !pip install numpy mido pygame --quiet

# %%
import numpy
print("NumPy è stato importato correttamente!")
# Out:
# NumPy è stato importato correttamente!

# %%
# Installazione delle librerie necessarie
# !pip install numpy
# !pip install mido
# !pip install pygame
# !pip install matplotlib
# !pip install pandas
# Out:
# Requirement already satisfied: numpy in /srv/conda/envs/notebook/lib/python3.10/site-packages (2.2.6)
# Requirement already satisfied: mido in /srv/conda/envs/notebook/lib/python3.10/site-packages (1.3.3)
# Requirement already satisfied: packaging in /srv/conda/envs/notebook/lib/python3.10/site-packages (from mido) (25.0)
# Requirement already satisfied: pygame in /srv/conda/envs/notebook/lib/python3.10/site-packages (2.6.1)
# Requirement already satisfied: matplotlib in /srv/conda/envs/notebook/lib/python3.10/site-packages (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: pandas in /srv/conda/envs/notebook/lib/python3.10/site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.22.4 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import numpy as np
import random
from mido import Message, MidiFile, MidiTrack, tempo2bpm
from typing import List, Dict, Any, Tuple
import time
import mido
from mido import Message, MidiFile, MidiTrack

# %%
class GeneticComposer:
    def __init__(self, population_size=100, generations=50, mutation_rate=0.10, tournament_size=3, elite_size=2):
        self.POPULATION_SIZE = population_size
        self.GENERATIONS = generations
        self.MUTATION_RATE = mutation_rate
        self.CROSSOVER_RATE = 0.7
        self.MUTATION_PITCH_STRENGTH = [-2, -1, 1, 2]
        self.TOURNAMENT_SIZE = tournament_size
        self.ELITE_SIZE = elite_size

        # Costanti musicali
        self.PITCH_RANGE = list(range(60, 72))
        self.MIN_PITCH = min(self.PITCH_RANGE)
        self.MAX_PITCH = max(self.PITCH_RANGE)
        self.MIN_VELOCITY = 50
        self.MAX_VELOCITY = 100
        self.DURATION_SET = [0.25, 0.5, 1.0]
        self.CHORD_PROGRESSION = [60, 65, 67, 60] * 2
        self.ACCORDI_VALIDI = {
            60: [60, 64, 67, 72],
            65: [65, 69, 72, 77],
            67: [67, 71, 74, 79],
        }

        # Lunghezza melodia
        self.MELODY_LENGTH = len(self.CHORD_PROGRESSION) * 4

        # Pesi della fitness
        self.W_HARMONY = 1.0
        self.W_FLUIDITY = 1.5
        self.W_VARIANCE = 0.5
        self.W_REPETITION = 0.3
        self.W_VELOCITY_PENALTY = 0.2

        self.ELITE_SIZE = 2

        # Debug
        self.DEBUG = False
        self.DEBUG_MUTATION = False
    # Genoma: un array di tuple, dove ogni tupla è (pitch, velocity) per una nota.
    # Non ottimizziamo la durata (duration) per mantenere la semplicità.
    # L'individuo sarà un dizionario simile a quelli usati nei tuoi notebook.
    # Esempio di genoma: [(60, 90), (62, 85), (64, 90), ...]
    
    def _create_random_genoma(self):
        genoma = []
        for _ in range(self.MELODY_LENGTH):
            pitch = random.randint(self.MIN_PITCH, self.MAX_PITCH)
            velocity = random.randint(self.MIN_VELOCITY, self.MAX_VELOCITY)
            duration_index = random.randint(0, len(self.DURATION_SET) - 1)
            genoma.append((pitch, velocity, duration_index))
        return genoma
    
    def _initialize_population(self) -> List[Dict[str, Any]]:
        """Inizializza la popolazione iniziale di genomi."""
        population = []
        for _ in range(self.POPULATION_SIZE):
            population.append({
                'genoma': self._create_random_genoma(),
                'fitness': 0.0  # Verrà calcolata
            })
        return population


    

    def _calculate_fitness(self, genoma: List[Tuple[int, int, int]]) -> Tuple[float, float, float]:
        """
        Calcola la fitness di un genoma musicale.
    
        Scopo:
            Valutare la qualità musicale di una melodia in base a criteri musicali e strutturali.
    
        Criteri:
            - Armonia: corrispondenza con gli accordi della progressione.
            - Fluidità: coerenza tra le altezze delle note.
            - Varianza: diversità nei pitch.
            - Ripetizione: penalità per eccessiva ripetizione.
            - Penalità di durata: punisce durate troppo brevi o troppo lunghe.
    
        Formula concettuale:
            Fitness = (W_HARMONY * Score_H) + (W_FLUIDITY * Score_F) + (W_VARIANCE * Score_V)
                      - (W_REPETITION * Penalità_R) - (W_VELOCITY_PENALTY * Penalità_V)
        """

        fitness_score = 0.0
        harmony_score = 0.0
        fluidity_score = 0.0
    
        # 1. Armonia (Coerenza con gli Accordi Target)
        for i, (pitch, velocity, duration_index) in enumerate(genoma):
            chord_index = i // 4
            target_chord_root = self.CHORD_PROGRESSION[chord_index]
            valid_notes = self.ACCORDI_VALIDI.get(target_chord_root, [])
    
            if pitch in valid_notes:
                harmony_score += 10.0
            else:
                harmony_score -= 5.0
    
        fitness_score += harmony_score * self.W_HARMONY
    
        # 2. Fluidità (salti melodici)
        for i in range(1, self.MELODY_LENGTH):
            pitch_prev = genoma[i-1][0]
            pitch_curr = genoma[i][0]
            pitch_difference = abs(pitch_curr - pitch_prev)
    
            if pitch_difference > 5:
                fluidity_score -= (pitch_difference - 5) * 1.5
    
        fitness_score += fluidity_score * self.W_FLUIDITY
    
        # 3. Varianza dei pitch
        pitches = [p for p, v, d in genoma]
        pitch_variance = np.var(pitches)
        fitness_score += pitch_variance * self.W_VARIANCE
    
        # 4. Ritmo
        durations = [self.DURATION_SET[d] for _, _, d in genoma]
        total_duration = sum(durations)
    
        duration_variance = np.var(durations)
        fitness_score += duration_variance * 0.5  # peso arbitrario
    
        if total_duration > self.MELODY_LENGTH * 0.5:
            fitness_score -= (total_duration - self.MELODY_LENGTH * 0.5) * 2.0
    
        # 5. Ripetizione tematica
        pitch_counts = {p: pitches.count(p) for p in set(pitches)}
        repeated_notes = sum(1 for count in pitch_counts.values() if count > 1)
        fitness_score += repeated_notes * self.W_REPETITION
    
        # 6. Penalità per velocity troppo bassa
        velocities = [v for p, v, d in genoma]
        low_velocity_penalty = sum(1 for v in velocities if v < 60)
        fitness_score -= low_velocity_penalty * self.W_VELOCITY_PENALTY
    
        # 7. Bonus per motivi ripetuti (sequenze di 3 note)
        motivi = [tuple(pitches[i:i+3]) for i in range(len(pitches)-2)]
        motivo_counts = {m: motivi.count(m) for m in set(motivi)}
        ripetizioni_motivi = sum(1 for count in motivo_counts.values() if count > 1)
        fitness_score += ripetizioni_motivi * 0.5
    
        return harmony_score, fluidity_score, fitness_score
    
    
    
    def _fitness(self, population: List[Dict[str, Any]]) -> List[Dict[str, Any]]:
        """Calcola la fitness per l'intera popolazione e ordina."""
        for individual in population:
            _, _, total_score = self._calculate_fitness(individual['genoma'])
            individual['fitness'] = total_score
            if self.DEBUG:
                print(f"Fitness calcolata: {total_score}")
    
        population.sort(key=lambda x: x['fitness'], reverse=True)
        return population




    def _selection(self, population: List[Dict[str, Any]]) -> List[Dict[str, Any]]:
        """
        Selezione basata su un approccio ibrido: elitismo e selezione casuale pesata.
        Mantiene il 20% dei migliori e seleziona il resto da un pool pesato.
        """
        num_elite = int(self.POPULATION_SIZE * 0.2)
        elite = population[:num_elite]
    
        candidates = population[num_elite:]
        total_fitness = sum(i['fitness'] for i in candidates)
    
        if total_fitness <= 0:
            weights = [1] * len(candidates)
        else:
            weights = [i['fitness'] / total_fitness for i in candidates]
    
        parents = random.choices(candidates, weights=weights, k=self.POPULATION_SIZE - num_elite)
        return elite + parents

    def _selection_tournament(self, population):
        """
        Selezione a torneo: mantiene l'élite e seleziona il resto scegliendo il migliore tra k candidati casuali.
        """
        selected = []
        num_elite = int(self.POPULATION_SIZE * 0.2)
        selected.extend(population[:num_elite])  # elitismo

        while len(selected) < self.POPULATION_SIZE:
            contenders = random.sample(population, self.TOURNAMENT_SIZE)
            winner = max(contenders, key=lambda x: x['fitness'])
            selected.append({'genoma': winner['genoma'].copy(), 'fitness': 0.0})
    
        return selected

    
    def _crossover(self, population: List[Dict[str, Any]]) -> List[Dict[str, Any]]:
        """
        Applica il Single Point Crossover.
        """
        new_population = []
    
        # Manteniamo l'individuo migliore non modificato (Elitismo)
        new_population.append(population[0])
    
        for i in range(1, self.POPULATION_SIZE // 2):
            parent1 = population[i * 2]
            parent2 = population[i * 2 + 1]
    
            if random.random() < self.CROSSOVER_RATE:
                point = random.randint(1, self.MELODY_LENGTH - 1)
    
                child1_genoma = parent1['genoma'][:point] + parent2['genoma'][point:]
                child2_genoma = parent2['genoma'][:point] + parent1['genoma'][point:]
    
                new_population.append({'genoma': child1_genoma, 'fitness': 0.0})
                new_population.append({'genoma': child2_genoma, 'fitness': 0.0})
            else:
                new_population.append(parent1)
                new_population.append(parent2)
    
        return new_population[:self.POPULATION_SIZE]
    
    def _mutation(self, population: List[Dict[str, Any]]) -> List[Dict[str, Any]]:
        """
        Applica la mutazione ai genomi: pitch/velocity prioritaria, durata ritmica separata.
        """
        for individual in population[1:]:  # Evita il migliore
            genoma = individual['genoma']
            for i in range(len(genoma)):
                pitch, velocity, duration_index = genoma[i]
    
                if random.random() < self.MUTATION_RATE:
                    pitch_delta = random.choice(self.MUTATION_PITCH_STRENGTH)
                    new_pitch = pitch + pitch_delta
                    new_pitch = max(self.MIN_PITCH, min(self.MAX_PITCH, new_pitch))
    
                    velocity_delta = random.randint(-10, 10)
                    new_velocity = velocity + velocity_delta
                    new_velocity = max(self.MIN_VELOCITY, min(self.MAX_VELOCITY, new_velocity))
    
                    genoma[i] = (new_pitch, new_velocity, duration_index)
    
                elif random.random() < 0.15:
                    new_duration_index = random.randint(0, len(self.DURATION_SET) - 1)
                    genoma[i] = (pitch, velocity, new_duration_index)
    
        return population


    def create_midi_file(self, genoma: List[Tuple[int, int, int]], filename: str = "melodia_evoluta.mid"):
        """Converte il genoma (melodia) nel file MIDI riproducibile."""
        mid = MidiFile()
        track = MidiTrack()
        mid.tracks.append(track)
    
        tempo = mido.bpm2tempo(120)
        track.append(mido.MetaMessage('set_tempo', tempo=tempo))
        track.append(mido.Message('program_change', program=1, time=0))
    
        ticks_per_beat = mid.ticks_per_beat
    
        for pitch, velocity, duration_index in genoma:
            duration = int(self.DURATION_SET[duration_index] * ticks_per_beat)
            track.append(Message('note_on', note=pitch, velocity=velocity, time=0))
            track.append(Message('note_off', note=pitch, velocity=velocity, time=duration))
    
        mid.save(filename)
        print(f"File MIDI salvato come: {filename}")
    
    
    def create_comparison_midi(self, initial: List[Tuple[int, int, int]], final: List[Tuple[int, int, int]], filename="confronto.mid"):
        mid = MidiFile()
        track = MidiTrack()
        mid.tracks.append(track)
    
        tempo = mido.bpm2tempo(120)
        track.append(mido.MetaMessage('set_tempo', tempo=tempo))
        track.append(mido.Message('program_change', program=1, time=0))
    
        ticks_per_beat = mid.ticks_per_beat
    
        for pitch, velocity, duration_index in initial:
            duration = int(self.DURATION_SET[duration_index] * ticks_per_beat)
            track.append(Message('note_on', note=pitch, velocity=velocity, time=0))
            track.append(Message('note_off', note=pitch, velocity=velocity, time=duration))
    
        track.append(Message('note_off', note=0, velocity=0, time=ticks_per_beat * 2))
    
        for pitch, velocity, duration_index in final:
            duration = int(self.DURATION_SET[duration_index] * ticks_per_beat)
            track.append(Message('note_on', note=pitch, velocity=velocity, time=0))
            track.append(Message('note_off', note=pitch, velocity=velocity, time=duration))
    
        mid.save(filename)
        print(f"File confronto MIDI salvato come: {filename}")
    
    def evolve(self, use_tournament=False):
        fitness_history = []
        import csv
        import pandas as pd
        import matplotlib.pyplot as plt
    
        population = self._initialize_population()
        population = self._fitness(population)


    
        initial_genome = population[0]['genoma']
        self.create_midi_file(initial_genome, filename="melodia_iniziale.mid")
    
        best_individual = population[0]
    
        print(f"Target melodia: {self.MELODY_LENGTH} note, {self.GENERATIONS} generazioni.")
        print("---------------------------------------------------------")
    
        with open("fitness_evoluzione.csv", "w", newline="") as f:
            writer = csv.writer(f, delimiter=';')
            writer.writerow(["Generazione", "Fitness Massima", "Fitness Media", "Fitness Minima", "Deviazione Std"])
    
        for generation in range(self.GENERATIONS):
            # 1. Selezione
            if use_tournament:
                selected = self._selection_tournament(population)
            else:
                selected = self._selection(population)
        
            # 2. Crossover
            offspring = self._crossover(selected)
        
            # 3. Mutazione
            offspring = self._mutation(offspring)
        
            # 4. Elitismo esplicito: copia i migliori ELITE_SIZE dalla generazione precedente
            elite_individuals = population[:self.ELITE_SIZE]
            population = elite_individuals + offspring[self.ELITE_SIZE:]
        
            # 5. Calcolo fitness
            population = self._fitness(population)

            current_max_fitness = max(ind['fitness'] for ind in population)
            current_avg_fitness = sum(ind['fitness'] for ind in population) / len(population)
            fitness_history.append((current_max_fitness, current_avg_fitness))
    
            fitness_values = [ind['fitness'] for ind in population]
            fitness_media = sum(fitness_values) / len(fitness_values)
            fitness_minima = min(fitness_values)
            fitness_std = np.std(fitness_values)
    
            with open("fitness_evoluzione.csv", "a", newline="") as f:
                writer = csv.writer(f, delimiter=';', quoting=csv.QUOTE_MINIMAL)
            
                # Converti i numeri in stringhe con virgola come separatore decimale
                fitness_max_str = str(round(population[0]['fitness'], 4)).replace('.', ',')
                fitness_avg_str = str(round(fitness_media, 4)).replace('.', ',')
                fitness_min_str = str(round(fitness_minima, 4)).replace('.', ',')
                fitness_std_str = str(round(fitness_std, 4)).replace('.', ',')
            
                writer.writerow([
                    generation + 1,
                    fitness_max_str,
                    fitness_avg_str,
                    fitness_min_str,
                    fitness_std_str
                ])

    
            if population[0]['fitness'] > best_individual['fitness']:
                best_individual = population[0]
    
            if (generation + 1) % 5 == 0 or generation == 0:
                print(f"Generazione {generation+1:2d}/{self.GENERATIONS} - Fitness Max: {best_individual['fitness']:.2f} (Pop. attuale: {population[0]['fitness']:.2f})")
    
        print("---------------------------------------------------------")
        print(f"Evoluzione completata. Fitness finale migliore: {best_individual['fitness']:.2f}")
    
        self.create_midi_file(best_individual['genoma'])
        self.create_comparison_midi(initial_genome, best_individual['genoma'])
    
        df = pd.read_csv("fitness_evoluzione.csv", sep=';')
        plt.figure(figsize=(10, 5))
        plt.plot(df["Generazione"], df["Fitness Massima"], label="Fitness Max", color='blue')
        plt.plot(df["Generazione"], df["Fitness Media"], label="Fitness Media", color='orange')
        plt.plot(df["Generazione"], df["Fitness Minima"], label="Fitness Min", color='red')
        plt.plot(df["Generazione"], df["Deviazione Std"], label="Deviazione Std", color='green')
        plt.xlabel("Generazione")
        plt.ylabel("Fitness")
        plt.title("Evoluzione della Fitness (Max vs Media)")
        plt.legend()
        plt.grid(True)
        plt.savefig("grafico_fitness.png")
        plt.show()
    
        print("Genoma iniziale:", initial_genome)
        print("Genoma finale:", best_individual['genoma'])
    
        initial_harmony_score = self._calculate_fitness(initial_genome)[0]
        final_harmony_score = self._calculate_fitness(best_individual['genoma'])[0]
        print(f"Note armoniche - Iniziale: {initial_harmony_score:.2f}, Finale: {final_harmony_score:.2f}")
    
        initial_pitches = [p for p, v, d in initial_genome]
        final_pitches = [p for p, v, d in best_individual['genoma']]
        print(f"Varianza pitch - Iniziale: {np.var(initial_pitches):.2f}, Finale: {np.var(final_pitches):.2f}")
    
        initial_jumps = [abs(initial_pitches[i+1] - initial_pitches[i]) for i in range(len(initial_pitches)-1)]
        final_jumps = [abs(final_pitches[i+1] - final_pitches[i]) for i in range(len(final_pitches)-1)]
        print(f"Media salti - Iniziale: {np.mean(initial_jumps):.2f}, Finale: {np.mean(final_jumps):.2f}")
    
        return best_individual, fitness_history


# Esecuzione del progetto!
composer = GeneticComposer()
melodia_ottimale = composer.evolve()

# Selezione pesata vs torneo
composer_pesata = GeneticComposer()
best_individual_pesata, history_pesata = composer_pesata.evolve(use_tournament=False)

composer_torneo = GeneticComposer()
best_individual_torneo, history_torneo = composer_torneo.evolve(use_tournament=True)

print("Fitness finale (pesata):", best_individual_pesata['fitness'])
print("Fitness finale (torneo):", best_individual_torneo['fitness'])

# 🔽 Test con torneo K=2 e K=5
composer_k2 = GeneticComposer(tournament_size=2)
best_k2, history_k2 = composer_k2.evolve(use_tournament=True)

composer_k5 = GeneticComposer(tournament_size=5)
best_k5, history_k5 = composer_k5.evolve(use_tournament=True)

print("Fitness finale (torneo K=2):", best_k2['fitness'])
print("Fitness finale (torneo K=5):", best_k5['fitness'])

# Analisi parametrica: melodico vs armonico
composer_melodico = GeneticComposer(mutation_rate=0.10)
composer_melodico.W_HARMONY = 1.0
composer_melodico.W_FLUIDITY = 3.0
melodia_melodica, history_melodica = composer_melodico.evolve()

composer_armonico = GeneticComposer(mutation_rate=0.10)
composer_armonico.W_HARMONY = 3.0
composer_armonico.W_FLUIDITY = 1.0
melodia_armonica, history_armonica = composer_armonico.evolve()

print("Melodica - Fitness finale:", melodia_melodica['fitness'])
print("Armonica - Fitness finale:", melodia_armonica['fitness'])
# Out:
# File MIDI salvato come: melodia_iniziale.mid
# Target melodia: 32 note, 50 generazioni.
# ---------------------------------------------------------
# Generazione  1/50 - Fitness Max: 3.61 (Pop. attuale: 3.61)
# Generazione  5/50 - Fitness Max: 3.61 (Pop. attuale: 3.61)
# Generazione 10/50 - Fitness Max: 32.79 (Pop. attuale: 32.79)
# Generazione 15/50 - Fitness Max: 32.79 (Pop. attuale: 32.79)
# Generazione 20/50 - Fitness Max: 34.49 (Pop. attuale: 34.49)
# Generazione 25/50 - Fitness Max: 34.49 (Pop. attuale: 34.49)
# Generazione 30/50 - Fitness Max: 34.49 (Pop. attuale: 34.49)
# Generazione 35/50 - Fitness Max: 34.49 (Pop. attuale: 34.49)
# Generazione 40/50 - Fitness Max: 34.49 (Pop. attuale: 34.49)
# Generazione 45/50 - Fitness Max: 34.49 (Pop. attuale: 34.49)
# Generazione 50/50 - Fitness Max: 34.49 (Pop. attuale: 34.49)
# ---------------------------------------------------------
# Evoluzione completata. Fitness finale migliore: 34.49
# File MIDI salvato come: melodia_evoluta.mid
# File confronto MIDI salvato come: confronto.mid
# Genoma iniziale: [(60, 56, 0), (66, 57, 0), (70, 70, 2), (68, 90, 2), (69, 90, 1), (64, 66, 2), (64, 82, 0), (67, 85, 1), (70, 80, 1), (62, 61, 2), (65, 86, 1), (70, 73, 1), (69, 86, 2), (67, 89, 0), (68, 57, 1), (67, 85, 2), (64, 86, 0), (64, 77, 0), (61, 86, 1), (69, 62, 0), (69, 70, 1), (65, 83, 0), (71, 67, 2), (67, 70, 0), (64, 82, 0), (60, 71, 0), (67, 60, 1), (68, 86, 1), (67, 62, 1), (64, 53, 1), (62, 60, 0), (64, 63, 1)]
# Genoma finale: [(65, 50, 0), (60, 92, 0), (64, 50, 2), (63, 52, 0), (66, 58, 0), (68, 53, 0), (69, 98, 2), (69, 100, 0), (71, 77, 2), (66, 66, 2), (64, 85, 2), (69, 78, 1), (65, 72, 0), (67, 55, 2), (71, 56, 1), (66, 100, 1), (60, 54, 1), (70, 55, 0), (67, 100, 1), (60, 78, 0), (64, 73, 1), (62, 78, 2), (67, 64, 0), (65, 96, 0), (71, 53, 1), (71, 54, 1), (66, 62, 1), (71, 57, 1), (71, 90, 0), (60, 92, 2), (63, 70, 2), (64, 76, 1)]
# Note armoniche - Iniziale: 20.00, Finale: 65.00
# Varianza pitch - Iniziale: 8.94, Finale: 12.40
# Media salti - Iniziale: 3.10, Finale: 3.71
# File MIDI salvato come: melodia_iniziale.mid
# Target melodia: 32 note, 50 generazioni.
# ---------------------------------------------------------
# Generazione  1/50 - Fitness Max: 6.35 (Pop. attuale: 6.35)
# Generazione  5/50 - Fitness Max: 55.49 (Pop. attuale: 55.49)
# Generazione 10/50 - Fitness Max: 55.49 (Pop. attuale: 55.49)
# Generazione 15/50 - Fitness Max: 55.49 (Pop. attuale: 55.49)
# Generazione 20/50 - Fitness Max: 55.49 (Pop. attuale: 55.49)
# Generazione 25/50 - Fitness Max: 55.49 (Pop. attuale: 55.49)
# Generazione 30/50 - Fitness Max: 55.49 (Pop. attuale: 55.49)
# Generazione 35/50 - Fitness Max: 55.49 (Pop. attuale: 55.49)
# Generazione 40/50 - Fitness Max: 55.49 (Pop. attuale: 55.49)
# Generazione 45/50 - Fitness Max: 55.49 (Pop. attuale: 55.49)
# Generazione 50/50 - Fitness Max: 55.49 (Pop. attuale: 55.49)
# ---------------------------------------------------------
# Evoluzione completata. Fitness finale migliore: 55.49
# File MIDI salvato come: melodia_evoluta.mid
# File confronto MIDI salvato come: confronto.mid
# Genoma iniziale: [(60, 98, 0), (68, 85, 2), (71, 93, 2), (67, 91, 0), (69, 76, 0), (65, 77, 2), (69, 82, 0), (70, 84, 0), (68, 93, 0), (63, 51, 2), (64, 73, 2), (67, 71, 2), (64, 91, 0), (68, 91, 1), (65, 58, 2), (65, 56, 0), (64, 60, 0), (69, 70, 0), (63, 74, 1), (64, 61, 1), (64, 75, 1), (60, 86, 1), (65, 99, 1), (68, 54, 1), (63, 95, 0), (67, 52, 2), (62, 52, 2), (69, 74, 2), (67, 69, 0), (70, 51, 1), (68, 53, 2), (66, 96, 1)]
# Genoma finale: [(60, 56, 0), (64, 95, 1), (64, 60, 2), (64, 60, 0), (67, 95, 0), (61, 63, 1), (68, 55, 0), (65, 50, 1), (70, 55, 1), (61, 57, 2), (67, 85, 0), (60, 58, 1), (64, 70, 1), (61, 88, 1), (60, 77, 0), (65, 80, 2), (60, 68, 0), (64, 57, 0), (60, 86, 0), (67, 92, 1), (69, 71, 1), (69, 100, 2), (63, 83, 1), (60, 98, 2), (67, 50, 2), (60, 92, 1), (60, 65, 2), (67, 50, 2), (66, 78, 1), (62, 86, 0), (66, 51, 0), (67, 89, 0)]
# Note armoniche - Iniziale: 20.00, Finale: 95.00
# Varianza pitch - Iniziale: 8.00, Finale: 10.19
# Media salti - Iniziale: 3.29, Finale: 4.03
# File MIDI salvato come: melodia_iniziale.mid
# Target melodia: 32 note, 50 generazioni.
# ---------------------------------------------------------
# Generazione  1/50 - Fitness Max: 27.79 (Pop. attuale: 27.79)
# Generazione  5/50 - Fitness Max: 75.84 (Pop. attuale: 75.84)
# Generazione 10/50 - Fitness Max: 158.18 (Pop. attuale: 158.18)
# Generazione 15/50 - Fitness Max: 196.28 (Pop. attuale: 196.28)
# Generazione 20/50 - Fitness Max: 217.74 (Pop. attuale: 217.74)
# Generazione 25/50 - Fitness Max: 243.04 (Pop. attuale: 243.04)
# Generazione 30/50 - Fitness Max: 270.86 (Pop. attuale: 270.86)
# Generazione 35/50 - Fitness Max: 270.86 (Pop. attuale: 270.86)
# Generazione 40/50 - Fitness Max: 285.08 (Pop. attuale: 285.08)
# Generazione 45/50 - Fitness Max: 285.08 (Pop. attuale: 285.08)
# Generazione 50/50 - Fitness Max: 285.08 (Pop. attuale: 285.08)
# ---------------------------------------------------------
# Evoluzione completata. Fitness finale migliore: 285.08
# File MIDI salvato come: melodia_evoluta.mid
# File confronto MIDI salvato come: confronto.mid
# Genoma iniziale: [(65, 76, 1), (70, 88, 1), (60, 54, 2), (70, 62, 0), (67, 100, 2), (65, 78, 2), (69, 55, 0), (69, 75, 0), (65, 69, 0), (71, 84, 0), (69, 61, 2), (63, 83, 0), (67, 75, 0), (71, 51, 2), (69, 63, 2), (67, 55, 2), (64, 50, 0), (63, 69, 2), (64, 51, 2), (71, 54, 0), (68, 74, 1), (65, 69, 0), (69, 88, 0), (68, 82, 1), (60, 66, 2), (62, 66, 1), (65, 73, 1), (70, 54, 1), (69, 73, 1), (66, 79, 1), (62, 93, 1), (64, 64, 1)]
# Genoma finale: [(60, 74, 2), (67, 50, 0), (67, 87, 1), (67, 67, 0), (69, 92, 2), (65, 78, 0), (65, 50, 0), (69, 75, 2), (67, 72, 2), (71, 84, 2), (71, 56, 0), (71, 50, 2), (67, 66, 0), (67, 83, 2), (67, 77, 0), (67, 92, 0), (64, 85, 2), (61, 83, 0), (64, 58, 1), (64, 76, 0), (69, 70, 0), (69, 87, 2), (69, 84, 1), (69, 51, 2), (70, 92, 1), (71, 93, 0), (71, 55, 2), (67, 85, 1), (64, 82, 2), (67, 93, 2), (64, 60, 1), (67, 70, 0)]
# Note armoniche - Iniziale: 20.00, Finale: 290.00
# Varianza pitch - Iniziale: 10.00, Finale: 7.83
# Media salti - Iniziale: 3.71, Finale: 1.90
# Fitness finale (pesata): 55.48623046875
# Fitness finale (torneo): 285.0757995605469
# File MIDI salvato come: melodia_iniziale.mid
# Target melodia: 32 note, 50 generazioni.
# ---------------------------------------------------------
# Generazione  1/50 - Fitness Max: -9.52 (Pop. attuale: -9.52)
# Generazione  5/50 - Fitness Max: 55.73 (Pop. attuale: 55.73)
# Generazione 10/50 - Fitness Max: 114.06 (Pop. attuale: 114.06)
# Generazione 15/50 - Fitness Max: 149.38 (Pop. attuale: 149.38)
# Generazione 20/50 - Fitness Max: 181.03 (Pop. attuale: 181.03)
# Generazione 25/50 - Fitness Max: 182.63 (Pop. attuale: 182.63)
# Generazione 30/50 - Fitness Max: 206.80 (Pop. attuale: 206.80)
# Generazione 35/50 - Fitness Max: 225.25 (Pop. attuale: 225.25)
# Generazione 40/50 - Fitness Max: 239.47 (Pop. attuale: 239.47)
# Generazione 45/50 - Fitness Max: 265.54 (Pop. attuale: 265.54)
# Generazione 50/50 - Fitness Max: 265.54 (Pop. attuale: 265.54)
# ---------------------------------------------------------
# Evoluzione completata. Fitness finale migliore: 265.54
# File MIDI salvato come: melodia_evoluta.mid
# File confronto MIDI salvato come: confronto.mid
# Genoma iniziale: [(68, 85, 1), (64, 87, 0), (67, 73, 2), (64, 72, 0), (65, 87, 0), (71, 51, 0), (63, 80, 2), (61, 78, 2), (60, 98, 0), (63, 65, 1), (67, 54, 0), (70, 60, 2), (62, 62, 0), (69, 65, 2), (64, 96, 2), (61, 93, 2), (68, 52, 2), (70, 51, 1), (60, 66, 0), (67, 64, 2), (65, 77, 1), (65, 82, 2), (63, 80, 2), (69, 93, 0), (67, 76, 1), (62, 52, 0), (66, 84, 1), (66, 96, 0), (71, 57, 2), (67, 86, 1), (61, 82, 0), (66, 68, 2)]
# Genoma finale: [(60, 87, 2), (60, 86, 0), (67, 93, 0), (60, 96, 0), (65, 54, 1), (69, 79, 2), (65, 75, 1), (69, 81, 1), (67, 85, 2), (65, 50, 2), (67, 90, 1), (67, 74, 0), (69, 83, 0), (67, 67, 0), (67, 76, 1), (67, 83, 2), (64, 63, 0), (60, 69, 1), (64, 61, 0), (64, 86, 2), (65, 68, 2), (62, 50, 1), (65, 81, 1), (69, 64, 0), (67, 92, 0), (71, 90, 2), (71, 62, 0), (71, 96, 2), (64, 73, 1), (67, 60, 0), (64, 92, 0), (64, 66, 1)]
# Note armoniche - Iniziale: 35.00, Finale: 275.00
# Varianza pitch - Iniziale: 10.05, Finale: 9.58
# Media salti - Iniziale: 4.13, Finale: 2.65
# File MIDI salvato come: melodia_iniziale.mid
# Target melodia: 32 note, 50 generazioni.
# ---------------------------------------------------------
# Generazione  1/50 - Fitness Max: 17.21 (Pop. attuale: 17.21)
# Generazione  5/50 - Fitness Max: 107.70 (Pop. attuale: 107.70)
# Generazione 10/50 - Fitness Max: 185.37 (Pop. attuale: 185.37)
# Generazione 15/50 - Fitness Max: 222.53 (Pop. attuale: 222.53)
# Generazione 20/50 - Fitness Max: 252.57 (Pop. attuale: 252.57)
# Generazione 25/50 - Fitness Max: 255.76 (Pop. attuale: 255.76)
# Generazione 30/50 - Fitness Max: 273.26 (Pop. attuale: 273.26)
# Generazione 35/50 - Fitness Max: 286.41 (Pop. attuale: 286.41)
# Generazione 40/50 - Fitness Max: 288.35 (Pop. attuale: 288.35)
# Generazione 45/50 - Fitness Max: 293.59 (Pop. attuale: 293.59)
# Generazione 50/50 - Fitness Max: 293.59 (Pop. attuale: 293.59)
# ---------------------------------------------------------
# Evoluzione completata. Fitness finale migliore: 293.59
# File MIDI salvato come: melodia_evoluta.mid
# File confronto MIDI salvato come: confronto.mid
# Genoma iniziale: [(67, 94, 2), (68, 69, 2), (60, 95, 2), (64, 67, 0), (70, 83, 0), (63, 73, 1), (69, 63, 2), (63, 73, 2), (65, 81, 2), (70, 92, 1), (67, 98, 2), (68, 63, 2), (63, 82, 2), (67, 68, 0), (63, 82, 0), (70, 98, 0), (66, 83, 1), (64, 51, 2), (64, 92, 1), (67, 53, 2), (65, 62, 0), (61, 60, 1), (60, 97, 1), (61, 55, 1), (66, 59, 0), (68, 74, 2), (64, 73, 0), (64, 70, 2), (63, 85, 1), (71, 56, 0), (67, 57, 1), (68, 90, 1)]
# Genoma finale: [(64, 64, 2), (60, 89, 1), (64, 98, 2), (60, 68, 2), (65, 61, 0), (69, 95, 2), (65, 72, 1), (69, 64, 1), (71, 82, 0), (71, 81, 1), (67, 98, 2), (67, 57, 0), (60, 60, 1), (67, 68, 0), (64, 93, 1), (67, 80, 2), (67, 84, 1), (67, 69, 2), (64, 92, 2), (67, 53, 0), (69, 58, 0), (65, 70, 2), (65, 63, 2), (65, 50, 1), (67, 62, 2), (67, 85, 0), (67, 61, 1), (71, 59, 0), (71, 100, 1), (67, 73, 0), (67, 94, 1), (60, 62, 0)]
# Note armoniche - Iniziale: 5.00, Finale: 305.00
# Varianza pitch - Iniziale: 8.88, Finale: 9.48
# Media salti - Iniziale: 3.58, Finale: 2.71
# Fitness finale (torneo K=2): 265.53566284179686
# Fitness finale (torneo K=5): 293.59052734375
# File MIDI salvato come: melodia_iniziale.mid
# Target melodia: 32 note, 50 generazioni.
# ---------------------------------------------------------
# Generazione  1/50 - Fitness Max: -42.47 (Pop. attuale: -42.47)
# Generazione  5/50 - Fitness Max: -5.33 (Pop. attuale: -5.33)
# Generazione 10/50 - Fitness Max: 16.06 (Pop. attuale: 16.06)
# Generazione 15/50 - Fitness Max: 22.45 (Pop. attuale: 22.45)
# Generazione 20/50 - Fitness Max: 22.45 (Pop. attuale: 22.45)
# Generazione 25/50 - Fitness Max: 22.45 (Pop. attuale: 22.45)
# Generazione 30/50 - Fitness Max: 22.45 (Pop. attuale: 22.45)
# Generazione 35/50 - Fitness Max: 22.45 (Pop. attuale: 22.45)
# Generazione 40/50 - Fitness Max: 22.45 (Pop. attuale: 22.45)
# Generazione 45/50 - Fitness Max: 22.45 (Pop. attuale: 22.45)
# Generazione 50/50 - Fitness Max: 22.45 (Pop. attuale: 22.45)
# ---------------------------------------------------------
# Evoluzione completata. Fitness finale migliore: 22.45
# File MIDI salvato come: melodia_evoluta.mid
# File confronto MIDI salvato come: confronto.mid
# Genoma iniziale: [(70, 99, 1), (65, 73, 0), (67, 83, 1), (60, 77, 2), (60, 98, 2), (63, 53, 0), (60, 72, 1), (66, 50, 2), (65, 96, 1), (64, 94, 2), (71, 85, 1), (71, 92, 0), (66, 86, 2), (61, 64, 0), (60, 66, 1), (65, 78, 0), (64, 61, 0), (67, 64, 1), (62, 71, 0), (60, 93, 2), (64, 94, 0), (70, 76, 1), (61, 90, 1), (67, 65, 1), (62, 55, 0), (67, 58, 0), (61, 83, 0), (66, 85, 0), (60, 50, 0), (64, 82, 0), (63, 98, 2), (63, 57, 1)]
# Genoma finale: [(68, 59, 0), (60, 66, 2), (60, 74, 0), (60, 72, 2), (65, 59, 1), (65, 73, 2), (60, 91, 1), (66, 64, 2), (71, 88, 2), (68, 52, 0), (60, 89, 2), (60, 72, 2), (60, 61, 0), (65, 62, 0), (65, 65, 0), (66, 77, 0), (66, 75, 0), (67, 50, 0), (66, 100, 2), (70, 96, 2), (65, 100, 2), (64, 86, 2), (68, 50, 0), (69, 75, 0), (71, 58, 1), (71, 64, 2), (64, 75, 0), (67, 90, 1), (68, 95, 0), (67, 84, 0), (70, 91, 2), (64, 86, 2)]
# Note armoniche - Iniziale: 5.00, Finale: 65.00
# Varianza pitch - Iniziale: 11.05, Finale: 12.38
# Media salti - Iniziale: 3.84, Finale: 2.77
# File MIDI salvato come: melodia_iniziale.mid
# Target melodia: 32 note, 50 generazioni.
# ---------------------------------------------------------
# Generazione  1/50 - Fitness Max: 39.17 (Pop. attuale: 39.17)
# Generazione  5/50 - Fitness Max: 160.34 (Pop. attuale: 160.34)
# Generazione 10/50 - Fitness Max: 160.34 (Pop. attuale: 160.34)
# Generazione 15/50 - Fitness Max: 160.34 (Pop. attuale: 160.34)
# Generazione 20/50 - Fitness Max: 175.09 (Pop. attuale: 175.09)
# Generazione 25/50 - Fitness Max: 175.09 (Pop. attuale: 175.09)
# Generazione 30/50 - Fitness Max: 175.09 (Pop. attuale: 175.09)
# Generazione 35/50 - Fitness Max: 175.09 (Pop. attuale: 175.09)
# Generazione 40/50 - Fitness Max: 175.09 (Pop. attuale: 175.09)
# Generazione 45/50 - Fitness Max: 175.09 (Pop. attuale: 175.09)
# Generazione 50/50 - Fitness Max: 175.09 (Pop. attuale: 175.09)
# ---------------------------------------------------------
# Evoluzione completata. Fitness finale migliore: 175.09
# File MIDI salvato come: melodia_evoluta.mid
# File confronto MIDI salvato come: confronto.mid
# Genoma iniziale: [(67, 77, 1), (64, 97, 2), (60, 88, 0), (65, 92, 1), (68, 94, 0), (69, 96, 0), (60, 68, 2), (67, 66, 1), (61, 52, 0), (65, 51, 1), (67, 73, 1), (71, 64, 0), (70, 63, 0), (60, 93, 1), (64, 85, 2), (66, 68, 0), (70, 71, 0), (63, 76, 0), (71, 97, 1), (67, 86, 1), (65, 64, 0), (64, 81, 1), (60, 60, 1), (71, 63, 1), (66, 53, 1), (69, 80, 1), (70, 78, 0), (67, 58, 1), (66, 72, 0), (60, 54, 1), (68, 80, 0), (63, 76, 0)]
# Genoma finale: [(64, 77, 0), (71, 94, 2), (66, 89, 0), (71, 84, 0), (62, 100, 1), (70, 86, 1), (65, 50, 2), (66, 100, 2), (67, 81, 2), (64, 96, 1), (67, 92, 2), (68, 76, 0), (70, 50, 2), (64, 70, 1), (64, 93, 2), (67, 72, 0), (67, 50, 2), (69, 94, 0), (67, 50, 0), (60, 75, 2), (65, 68, 0), (65, 78, 0), (62, 98, 0), (64, 50, 0), (66, 100, 0), (67, 64, 0), (64, 95, 2), (64, 100, 0), (69, 100, 2), (62, 80, 2), (60, 62, 0), (60, 50, 2)]
# Note armoniche - Iniziale: 20.00, Finale: 65.00
# Varianza pitch - Iniziale: 12.19, Finale: 9.06
# Media salti - Iniziale: 4.45, Finale: 3.23
# Melodica - Fitness finale: 22.4498779296875
# Armonica - Fitness finale: 175.09249877929688

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

# Estrai le serie di fitness massima
plt.plot([f[0] for f in history_pesata], label="Pesata", color='blue')
plt.plot([f[0] for f in history_torneo], label="Torneo", color='green')
plt.plot([f[0] for f in history_melodica], label="Melodico", color='orange')
plt.plot([f[0] for f in history_armonica], label="Armonico", color='red')

plt.xlabel("Generazione")
plt.ylabel("Fitness Massima")
plt.title("Confronto Evolutivo tra Strategie e Configurazioni")
plt.legend()
plt.grid(True)
plt.savefig("grafico_confronto_strategie.png")
plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.plot([f[0] for f in history_k2], label="Torneo K=2", color='purple')
plt.plot([f[0] for f in history_k5], label="Torneo K=5", color='brown')

plt.xlabel("Generazione")
plt.ylabel("Fitness Massima")
plt.title("Confronto Evolutivo per Dimensione Torneo K")
plt.legend()
plt.grid(True)
plt.savefig("grafico_torneo_k.png")
plt.show()
